# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Read dataset

# %%
# First, we need to set the display options for pandas to show all columns (otherwise it won't show all columns)
pd.set_option('display.max_columns', None)

# Next, we need to read the data from the CSV file
plants_df = pd.read_csv('../data/cleaned_data.csv')

pd.set_option('max_colwidth', 100)  # Adjust the value as needed
plants_df.head()
# Out:
#                    Name  Kingdom          Clade      Clade_2   Clade_3  \
# 0                Acacia  Plantae  Tracheophytes  Angiosperms  Eudicots
# 1        Acacia ammobia  Plantae  Tracheophytes  Angiosperms  Eudicots
# 2  Acacia estrophiolata  Plantae  Tracheophytes  Angiosperms  Eudicots
# 3                 Maple  Plantae  Tracheophytes  Angiosperms  Eudicots
# 4       Acer leucoderme  Plantae  Tracheophytes  Angiosperms  Eudicots
#
#   Clade_4       Order       Family          Subfamily         Clade_5   Genus  \
# 0  Rosids     Fabales     Fabaceae   Caesalpinioideae  Mimosoid clade  Acacia
# 1  Rosids     Fabales     Fabaceae   Caesalpinioideae  Mimosoid clade  Acacia
# 2  Rosids     Fabales     Fabaceae   Caesalpinioideae  Mimosoid clade  Acacia
# 3  Rosids  Sapindales  Sapindaceae  Hippocastanoideae             NaN    Acer
# 4  Rosids  Sapindales  Sapindaceae                NaN             NaN    Acer
#
# ...

# %% [markdown]
# ### Combine columns (ccording to their similar content)

# %%
# Define a custom function to combine columns
def combine_columns(row, columns):
    parts = []
    
    for column in columns:
        if not pd.isna(row[column]):
            parts.append(row[column])
    
    return ''.join(parts)

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Taxonomy', 
    'Taxon and naming', 
    'Nomenclature and taxonomy', 
    'Taxonomy and naming', 
    'Taxonomic reclassification',
    'Naming',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Taxonomy'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Taxonomy'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Cultivation', 
    'Cultivation and uses', 
    'Domestic cultivation', 
    'United States cultivation',
    'Growing',
    'Processing',
    'Germination',
    'Distribution and cultivation',
    'Natural insect resistance and its potential use in agriculture'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Cultivation'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Cultivation'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Habitat',
    'Habitat and range',
    'Habitat and distribution',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Habitat'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Habitat'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Distribution and habitat',
    'Distribution',
    'Distribution and ecology',
    'Range',
    'Origin and distribution',
    'Origins',
    'Range and climate',
    'History and distribution',
    'Characteristics and habitat'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Distribution'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'Distribution'
column_to_keep2 = 'Characteristics and habitat'
column_to_keep3 = 'History and distribution'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and col != column_to_keep2 and col != column_to_keep3 ]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Characteristics and habitat',
    'Characteristics',
    'Botanical characteristics',
    'Structure and physiology',
    'Colors and soil acidity',
    'Frost intolerance',
    'Appearance',
    'Bananas and plantains',
    'Varieties'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Characteristics'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Characteristics'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Conservation status',
    'Conservation status in the United States',
    'Conservation'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Conservation'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Conservation'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
   'Etymology',
   'Etymology and other names',
   'Etymology and taxonomy',
   'Etymology and common names',
   'History, cultivation, and etymology'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Etymology'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Etymology'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Medicinal use',
    'Medicinal usage',
    'Medicine',
    'Benefits to human health',
    'Herbalism',
    'Claimed effectiveness against COVID-19',
    'Non-food applications'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Medicine'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'Medicine'
column_to_keep2 = 'Non-food applications' # because it will be combined in other column
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and col != column_to_keep2]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

#plants_df['Medicine']

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Nutritional content',
    'Nutrition and phytochemicals',
    'Nutritional aspects',
    'Nutritional value'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Nutrition'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Nutrition'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Allergenicity',
    'As an allergen',
    'Itch-inducing properties',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Allergenicity'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Allergenicity'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Natural history',
    'History',
    'Garden history',
    'History and distribution',
    'Notable trees',
    'Culture and history'
]

# Apply the custom function to create the new 'Combined' column
plants_df['History'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'History'
column_to_keep2 = 'Culture and history'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and col != column_to_keep2]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'In culture',
    'Culture',
    'Culture and history',
    'Cultural significance',
    'In popular culture',
    'Mythology',
    'Folklore'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Culture'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Culture'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Genetics',
    'Genetics and taxonomy',
    'Genetics and breeding',
    'Evolution',
    'Phylogeny',
    'Genome and transcriptomes',
    'Genome',
    'Genomics',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Genetics'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Genetics'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'As an introduced and invasive species',
    'Invasive species'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Invasive species'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Invasive species'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Pests and diseases',
    'Diseases',
    'Diseases on plants',
    'Diseases and pests',
    'Predators'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Pests and diseases'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Pests and diseases'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Uses',
    'Usage',
    'Use',
    'Yield',
    'General usage',
    'History and uses',
    'Insect repellent',
    'Chemistry, toxicity, and uses',
    'Non-food applications'
]


# Apply the custom function to create the new 'Combined' column
plants_df['Uses'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'Uses'
column_to_keep2 = 'Chemistry, toxicity, and uses'
column_to_keep3 = 'Cultivation and Uses'
column_to_keep4 = 'Non-food applications'

columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and 
                    col != column_to_keep2 and col != column_to_keep3 and col != column_to_keep4]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Chemistry',
    'Chemical constituents',
    'Chemical composition',
    'Plant chemistry'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Chemistry'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'Chemistry'
column_to_keep2 = 'Chemistry, toxicity, and uses'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and col != column_to_keep2]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Phytochemicals',
    'Phytochemistry'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Phytochemicals'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep1 = 'Phytochemicals'
column_to_keep2 = 'Phytochemistry and potential toxicity'

columns_to_drop = [col for col in columns_to_combine if col != column_to_keep1 and col != column_to_keep2]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Food',
    'Culinary uses'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Culinary uses'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Culinary uses'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)


# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
   'Chemistry',
   'Phytochemicals',
   'Natural chemotypes with distinct ecology',
   'Chemistry, toxicity, and uses',
   'Phytochemistry and potential toxicity',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Chemistry and Composition'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_combine)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Ecology',
    'Ecological benefits',
    'Ecology and conservation status',
    'Ecological importance',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Ecology'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Ecology'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Description',
    'Distribution',
    'Fossil record',
    'History',
    'Types', # about walnut species
    'Varieties and similar species', # extra info for V. viride
    'Domestication', # extra info about sunflowers
    'Overview',
    'Description and ecology',
    'Rice-growing environments',
    'Invasive species',
    'Agriculture',
    'Pollination',
    'Climatic and soil requirements',
    'Names',
    'Protection',
    'Symbolism',
    'Status as a weed',
    'Alternative names',
    'Identification',
    'Systematics',
    'Growth',
    'As a weed',
    'Culture',
    'Differentiation from Florida maple',
]

# Apply the custom function to create the new 'Combined' column
plants_df['Description'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Description'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %%
# Define the columns you want to combine
columns_to_combine = [
    'Threats',
    'Biological activity',
    'Host plant',
    'Control',
    'Conservation',
    'Storage',
    'Pests and diseases'
]

# Apply the custom function to create the new 'Combined' column
plants_df['Threats and Control'] = plants_df.apply(combine_columns, axis=1, columns=columns_to_combine)

column_to_keep = 'Threats and Control'
columns_to_drop = [col for col in columns_to_combine if col != column_to_keep]

# Drop the original columns if needed
plants_df = plants_df.drop(columns=columns_to_drop)

# plants_df.head()

# %% [markdown]
# ### Clean merged data and fill empty spaces with Nan values

# %%
for col in plants_df:
    plants_df[col] = plants_df[col].str.replace(r'[\n\r]', '', regex=True).str.strip()
    plants_df[col] = plants_df[col].replace('', np.nan)

# %%
plants_df.count()
# Out:
# Name                         403
# Kingdom                      384
# Clade                        383
# Clade_2                      372
# Clade_3                      366
#                             ...
# Supertribe                     1
# Farming techniques             1
# Nutrition                      5
# Chemistry and Composition     13
# Threats and Control           25
# Length: 63, dtype: int64

# %%
num_columns = plants_df.shape[1]
print(f'The DataFrame has {num_columns} columns.')
# Out:
# The DataFrame has 63 columns.

# %% [markdown]
# ### Remove irrelevant columns

# %%
plants_df = plants_df.drop(columns=[
    'Farming techniques',
    'Non-food applications',
    'Human genetics in relation to taste',
    'Supertribe',
    'Suborder',
    'Synonym lists',
    'Comparison between zoology and botany',
    'Subspecies and Variants',
    'Named hybrids involving black oak',
    'Subdivisions',
    'Common names',
    'Botany',
    'Global production',
    'Economic aspects',
    'Subsection',
    'Landscaping',
    'Horticulture',
    'Production',
    'Tall timber',
    'Varieties, hybrids and cultivars',
    'Classification',
    'Selected species',
    'Terminology',
    'Subspecies',
    'Series',
    'Species.1',
    'Breeding',
    'Cultivars'
])

# %% [markdown]
# ### Extract Origin Country

# %%
# List of possible countries
countries_list = [
    'USA', 'UK', 'Canada', 'Mexico', 'Argentina', 'Brazil', 'Chile', 'Peru', 'Colombia',
    'United Kingdom', 'France', 'Germany', 'Italy', 'Spain', 'Russia', 'Netherlands', 'Switzerland',
    'Australia', 'New Zealand', 'Japan', 'China', 'India', 'South Korea', 'Singapore',
    'South Africa', 'Nigeria', 'Kenya', 'Egypt', 'Ghana', 'Morocco', 'Ethiopia', 'Tanzania',
    'Saudi Arabia', 'United Arab Emirates', 'Turkey', 'Iran', 'Israel', 'Qatar', 'Jordan',
    'Thailand', 'Indonesia', 'Malaysia', 'Philippines', 'Vietnam', 'Cambodia', 'Laos', 'Myanmar',
    'Africa', 'Antarctica', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'
]

# Define a function to extract origin countries from the description
def extract_origin_countries(text):
    if isinstance(text, str):  # Check if the value is a string
        # List of keywords indicating country of origin
        keywords = ['origin', 'native', 'born', 'originally from', 'originating from', 'naturalizes', 'natural', 'habitats']

        # Create the country pattern dynamically
        country_pattern = r'(?:\b(?:' + '|'.join(countries_list) + r')\b)'

        origin_countries = []
        sentences = text.split('.')

        for sentence in sentences:
            if any(keyword in sentence.lower() for keyword in keywords):
                matches = re.findall(country_pattern, sentence, re.IGNORECASE)
                if matches:
                    origin_countries.extend(matches)

        return ', '.join(origin_countries) if origin_countries else np.nan
    else:
        return np.nan

# Apply the function to create the 'Origin Country' column
plants_df['Origin Country'] = plants_df['Introduction'] + plants_df['Description']
plants_df['Origin Country'] = plants_df['Origin Country'].apply(extract_origin_countries)


plants_df['Origin Country']
# Out:
# 0      Africa, Australia, Indonesia, China, Philippines
# 1                                             Australia
# 2                                             Australia
# 3                                                   NaN
# 4                                                   NaN
#                              ...
# 398                                                 NaN
# 399                                                 NaN
# 400                                 Iran, North America
# 401                                                 NaN
# 402                                                 NaN
# Name: Origin Country, Length: 403, dtype: object

# %% [markdown]
# ### Final dataframe treated

# %%
filtered_df = plants_df[plants_df['Name'].str.len() > 40]

# Set the display option to show the full content of a column
pd.set_option('display.max_colwidth', None)

# Display the filtered DataFrame
print(filtered_df['Name'])

# Reset the display option to its default value
pd.reset_option('display.max_colwidth')
# Out:
# 70     This species has long been known under the name Azolla caroliniana. However, research by Evrard & Van Hove  found that the type specimen of A. caroliniana actually consists of plants of Azolla filiculoides and so the name caroliniana has always been improperly applied to this species.
# 308        The Latin specific epithet palustris means "of marshland" or "of swamps", referring to its natural habitat.The common name "pin oak" is possibly due to the many small, slender twigs, but may also be from the historical use of the hard wood for pins in wooden building construction.
# 395                                                                                                                                                                                                                  The generic name Viburnum originated in Latin, where it referred to V. lantana.
# Name: Name, dtype: object

# %%
# Rewrite 3 Name rows that have extra text
plants_df.at[70, 'Name'] = 'Azolla caroliniana'
plants_df.at[308, 'Name'] = 'Quercus palustris'
plants_df.at[395, 'Name'] = 'Viburnum'

# counts the number of non-null entries for each column
print(plants_df.count())
# Out:
# Name                         403
# Kingdom                      384
# Clade                        383
# Clade_2                      372
# Clade_3                      366
# Clade_4                      290
# Order                        384
# Family                       384
# Subfamily                     90
# Clade_5                       10
# Genus                        380
# Introduction                 351
# Taxonomy                      72
# Ecology                       70
# Toxicity                      19
# Species                      303
# Description                  214
# Section                       42
# Uses                          40
# Tribe                         45
# Habitat                       12
# Cultivation                   57
# Genetics                      14
# Subgenus                      42
# Subtribe                      16
# Etymology                     43
# Division                      18
# Class                         18
# ...

# %% [markdown]
# ### Reorder columns

# %%
new_column_order=['Name',
                  'Introduction',
                  'Kingdom','Division','Class',
                  'Clade','Clade_2','Clade_3','Clade_4','Clade_5',
                  'Order',
                  'Tribe', 'Subtribe',
                  'Family','Subfamily',
                  'Genus','Subgenus',
                  'Species',
                  'Section',
                  'Description', 'Origin Country', 'Characteristics', 'Habitat',
                  'Taxonomy','Ecology', 
                  'Etymology', 'Genetics','Medicine','Nutrition','Chemistry and Composition','Toxicity','Allergenicity',
                  'Uses','Culinary uses','Cultivation',
                  'Threats and Control']

plants_df = plants_df[new_column_order]

# %% [markdown]
# ### Export resulting dataframe into a .CSV file

# %%
# Save the resulting DataFrame to a CSV file
plants_df.to_csv('../data/transformed_data.csv', index=False)
